# %% [markdown]
# <a href="https://colab.research.google.com/github/sudhanthiran/Python_Code_iNeuron/blob/Python-Assignments/Sudhanthiran_ML6JUN_Data_visualization_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets

# %% [markdown]
# In this assignment students have to transform iris data into 3 dimensions
# and plot a 3d chart with transformed dimensions and colour each data
# point with specific class.

# %%
iris = datasets.load_iris()
fig = plt.figure(1, figsize=(8, 6))
ax = Axes3D(fig, elev=-150, azim=110)

three_dim_data = decomposition.PCA(n_components=3).fit_transform(iris.data)

ax.scatter(three_dim_data[:, 0], three_dim_data[:, 1], three_dim_data[:, 2],c=iris.target)

ax.set_title("3 Dimentional Plot with PCA reduction")
ax.set_xlabel("1D")
ax.set_ylabel("2D")
ax.set_zlabel("3D")

plt.show()

# %% [markdown]
# ##2D Plot with Categorical features as Sepel Area and petal Area and Iris type

# %%
import pandas as pd
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
# load dataset into Pandas DataFrame
df = pd.read_csv(url, names=['sepal length','sepal width','petal length','petal width','target'])

df1 = pd.DataFrame(columns=['Sepal Area','Petal Area'])

sepal_area = df.loc[: , "sepal length":"sepal width"]
petal_area = df.loc[: , "petal length":"petal width"]

df1["Sepal Area"] = sepal_area.product(axis=1)
df1["Petal Area"] = petal_area.product(axis=1)

finalDf = pd.concat([df1, df[['target']]], axis = 1)

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_title("Petal Area Vs Sepal Area")
ax.set_xlabel('Petal Area', fontsize = 15)
ax.set_ylabel('Sepal Area', fontsize = 15)

targets = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['target'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'Petal Area']
               , finalDf.loc[indicesToKeep, 'Sepal Area']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()
